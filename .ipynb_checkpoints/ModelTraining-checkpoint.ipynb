# %% [markdown]
# # Training Model

# %%
# importing libraries
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
# importing datasets
train_df = pd.read_csv('clean_train.csv')
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.shape
# Out:
# (1460, 77)

# %%
test_df = pd.read_csv('clean_test.csv')
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         Lvl    AllPub    Inside  ...           0             0         0
# 1         Lvl    AllPub    Corner  ...          36             0         0
# 2         Lvl    AllPub    Inside  ...          34             0         0
# 3         Lvl    AllPub    Inside  ...          36             0         0
# 4         HLS    AllPub    Inside  ...          82             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.shape
# Out:
# (1459, 76)

# %%
# combine both datasets
df = pd.concat([train_df, test_df], axis=0) 
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1454         Lvl    AllPub    Inside  ...             0         0           0
# 1455         Lvl    AllPub    Inside  ...             0         0           0
# 1456         Lvl    AllPub    Inside  ...             0         0           0
# 1457         Lvl    AllPub    Inside  ...             0         0           0
# 1458         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (2919, 77)

# %%
# get list of categorical columns
categorical_columns = list()

for col in df.columns:
    if df[col].dtype == object:
        categorical_columns.append(col)

categorical_columns
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
# create function for generating dummies
def one_hot_encode(columns):
    final_df = df.copy()
        
    for col in columns:
        print(col)
        temp_df = pd.get_dummies(df[col], prefix=col, prefix_sep='_')
        final_df.drop([col], axis=1, inplace=True)
        final_df = pd.concat([final_df, temp_df], axis=1)
    
    return final_df

# %%
# create dummies for categorical variables
final_df = one_hot_encode(categorical_columns)
final_df
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...

# %%
final_df.shape
# Out:
# (2919, 276)

# %%
# separate training and testing dataset
train = final_df.iloc[:1460, :]
test = final_df.iloc[1460:, :]

# %%
train.shape
# Out:
# (1460, 276)

# %%
train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0       706.0  ...           False         False
# 1          1976         0.0       978.0  ...           False         False
# 2          2002       162.0       486.0  ...           False         False
# 3          1970         0.0       216.0  ...           False         False
# 4          2000       350.0       655.0  ...           False         False
#
# ...

# %%
test.shape
# Out:
# (1459, 276)

# %%
test.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# 0       1961          1961         0.0       468.0  ...           False
# 1       1958          1958       108.0       923.0  ...           False
# 2       1997          1998         0.0       791.0  ...           False
# 3       1998          1998        20.0       602.0  ...           False
# 4       1992          1992         0.0       263.0  ...           False
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
# create the training input and output
X_train = train.drop(['SalePrice'], axis=1)
Y_train = train['SalePrice']

# %%
X_train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0       706.0  ...           False         False
# 1          1976         0.0       978.0  ...           False         False
# 2          2002       162.0       486.0  ...           False         False
# 3          1970         0.0       216.0  ...           False         False
# 4          2000       350.0       655.0  ...           False         False
#
# ...

# %%
Y_train.head()
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64

# %%
# create the test set
test = test.drop(['SalePrice'], axis=1)
test.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# 0       1961          1961         0.0       468.0  ...           False
# 1       1958          1958       108.0       923.0  ...           False
# 2       1997          1998         0.0       791.0  ...           False
# 3       1998          1998        20.0       602.0  ...           False
# 4       1992          1992         0.0       263.0  ...           False
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
# train model
import xgboost

# %%
model = xgboost.XGBRegressor()
model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# save the model as pickel file
import pickle
pickle.dump(model, open('modelv1.pkl', 'wb'))

# %%
# get predictions
predictions = pd.DataFrame({'SalePrice':model.predict(test)})
predictions
# Out:
#           SalePrice
# 0     128190.695312
# 1     152174.265625
# 2     181630.078125
# 3     188409.484375
# 4     194575.734375
# ...             ...
# 1454   82349.742188
# 1455   72548.093750
# 1456  166236.265625
# 1457  101260.000000
# 1458  206189.125000
#
# [1459 rows x 1 columns]

# %%
# create submission file
submission_df = pd.concat([test['Id'], predictions], axis=1)
submission_df
# Out:
#         Id      SalePrice
# 0     1461  128190.695312
# 1     1462  152174.265625
# 2     1463  181630.078125
# 3     1464  188409.484375
# 4     1465  194575.734375
# ...    ...            ...
# 1454  2915   82349.742188
# 1455  2916   72548.093750
# 1456  2917  166236.265625
# 1457  2918  101260.000000
# 1458  2919  206189.125000
#
# [1459 rows x 2 columns]

# %%
submission_df.to_csv('final_submission.csv', index=False)
